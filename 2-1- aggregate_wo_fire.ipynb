# %%
# Final full script to merge ERA5, CHLA, TURB, LSWT, and export one CSV per lake

import os
import glob
import pandas as pd

def load_weekly_mean_files(folder, variable_name, required=True, lake_ids_filter=None):
    files = sorted(glob.glob(os.path.join(folder, f"*_{variable_name.upper()}_weekly.csv")))
    combined = []

    for file in files:
        try:
            df = pd.read_csv(file)
            df = df[["Lake_ID", "Year", "Week", "mean"]].copy()
            if lake_ids_filter is not None:
                df = df[df["Lake_ID"].isin(lake_ids_filter)]
            df.rename(columns={"mean": f"{variable_name.lower()}_mean"}, inplace=True)
            combined.append(df)
        except Exception as e:
            if required:
                print(f"[Required] Failed to process {file}: {e}")
            else:
                print(f"[Optional] Skipped {file} due to error: {e}")

    if combined:
        return pd.concat(combined, ignore_index=True)
    else:
        return pd.DataFrame()

def load_era5_data(era5_folder):
    files = sorted(glob.glob(os.path.join(era5_folder, "ERA5Land_Weekly_Catchments_*.csv")))
    dfs = []

    for file in files:
        df = pd.read_csv(file)
        df.rename(columns={"year": "Year", "week": "Week"}, inplace=True)
        dfs.append(df)

    return pd.concat(dfs, ignore_index=True)

def merge_all_sources_and_save(era5_folder, chla_folder, turb_folder, lswt_folder, output_folder):
    # Load ERA5 and get full list of Lake_IDs
    era5 = load_era5_data(era5_folder)
    valid_lakes = era5["Lake_ID"].unique()

    # Load CHLA, TURB (required), LSWT (optional)
    chla = load_weekly_mean_files(chla_folder, "CHLA", required=True, lake_ids_filter=valid_lakes)
    turb = load_weekly_mean_files(turb_folder, "TURB", required=True, lake_ids_filter=valid_lakes)
    lswt = load_weekly_mean_files(lswt_folder, "LSWT", required=False, lake_ids_filter=valid_lakes)


    # Find only lakes that are present in both CHLA and TURB files
    chla_ids = set(chla["Lake_ID"].unique())
    turb_ids = set(turb["Lake_ID"].unique())
    era5_ids = set(era5["Lake_ID"].unique())

    # Eligible = in CHLA ∩ TURB ∩ ERA5
    eligible_lake_ids = chla_ids & turb_ids & era5_ids

    # Excluded = (CHLA ∪ TURB) - eligible or not in ERA5
    excluded_lake_ids = (chla_ids | turb_ids) - eligible_lake_ids
    excluded_due_to_era5 = (chla_ids & turb_ids) - era5_ids

    # Print both groups
    missing_from_output = era5_ids - eligible_lake_ids
    print("Lakes in ERA5 but excluded due to missing CHLA or TURB:", sorted(missing_from_output))
    print(f"Count: {len(missing_from_output)}")


    # Filter ERA5 to only eligible lakes
    merged = era5[era5["Lake_ID"].isin(eligible_lake_ids)].copy()

    # Merge all variables
    merged = merged.merge(chla, on=["Lake_ID", "Year", "Week"], how="left")
    merged = merged.merge(turb, on=["Lake_ID", "Year", "Week"], how="left")
    merged = merged.merge(lswt, on=["Lake_ID", "Year", "Week"], how="left")

    # Create output folder
    os.makedirs(output_folder, exist_ok=True)

    # Save one CSV per eligible lake
    for lake_id in sorted(eligible_lake_ids):
        lake_df = merged[merged["Lake_ID"] == lake_id]
        output_path = os.path.join(output_folder, f"Lake_{lake_id}.csv")
        lake_df.to_csv(output_path, index=False)
        print(f"Saved: {output_path}")


# Example use:
# merge_all_sources_and_save("ERA5", "CHLA", "TURB", "LSWT", "Merged_Lake_CSVs")

# %%
result_df = merge_all_sources_and_save("Datasets/GEE/ECMWF_raw", "Datasets/CNR/weekly/CHLA", "Datasets/CNR/weekly/turbidity", "Datasets/CNR/weekly/LSWT", "Datasets/Merged_Lake_CSVs")
# Out:
# Lakes in ERA5 but excluded due to missing CHLA or TURB: [np.int64(2), np.int64(168), np.int64(337), np.int64(723), np.int64(300009430)]
# Count: 5
# Saved: Datasets/Merged_Lake_CSVs\Lake_5.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_6.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_12.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_13.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_15.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_21.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_26.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_27.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_28.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_31.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_37.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_38.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_44.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_54.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_57.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_63.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_68.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_72.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_76.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_82.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_101.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_107.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_110.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_114.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_118.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_122.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_127.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_128.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_130.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_146.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_151.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_153.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_155.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_158.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_159.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_165.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_172.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_174.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_176.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_191.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_194.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_198.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_200.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_201.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_222.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_223.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_224.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_225.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_234.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_235.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_236.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_243.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_245.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_248.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_251.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_253.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_257.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_266.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_270.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_276.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_278.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_280.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_281.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_282.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_285.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_288.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_290.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_293.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_298.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_301.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_303.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_309.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_323.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_326.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_335.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_340.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_345.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_349.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_350.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_351.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_353.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_356.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_357.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_362.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_363.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_366.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_368.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_370.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_374.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_375.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_378.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_380.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_384.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_385.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_391.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_392.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_394.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_399.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_402.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_404.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_405.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_409.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_411.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_419.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_421.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_423.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_432.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_437.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_441.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_450.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_451.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_452.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_454.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_457.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_464.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_467.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_468.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_474.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_477.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_482.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_486.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_493.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_501.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_503.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_507.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_508.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_516.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_517.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_523.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_529.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_534.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_535.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_538.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_544.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_545.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_546.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_555.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_556.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_558.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_559.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_565.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_566.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_567.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_570.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_571.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_572.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_573.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_581.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_590.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_624.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_633.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_646.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_672.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_677.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_684.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_702.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_713.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_728.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_730.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_733.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_746.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_748.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_754.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_761.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_770.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_771.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_779.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_797.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_804.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_810.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_824.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_836.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_837.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_872.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_883.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_904.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_905.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_908.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_910.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_929.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_931.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_949.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_977.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1003.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1009.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1026.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1053.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1062.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1071.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1075.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1116.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1128.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1129.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1148.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1154.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1169.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1188.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1193.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1199.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1221.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1222.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1237.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1249.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1344.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1359.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1361.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1368.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1375.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1424.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1425.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1434.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1437.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1467.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1479.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1493.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1498.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1509.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1510.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1547.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1567.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1582.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1594.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1623.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1627.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1676.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1703.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1706.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1714.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1735.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1748.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1756.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1761.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1815.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1818.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1908.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1910.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1945.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_1989.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2012.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2021.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2032.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2064.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2097.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2102.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2132.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2157.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2162.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2168.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2179.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2190.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2192.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2245.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2253.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2263.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2330.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2345.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2367.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2368.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2369.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2418.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2420.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2421.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2436.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2484.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2544.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2560.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2594.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2595.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2616.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2673.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2693.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2709.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2724.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2731.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2799.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2812.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2898.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2944.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2970.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2974.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2978.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_2988.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3040.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3079.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3135.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3188.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3231.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3238.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3243.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3392.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3397.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3493.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3523.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3570.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3604.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_3614.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_4503.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_5506.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_6048.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_6561.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_7739.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_9322.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_10161.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_10421.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_12200.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_12471.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_13377.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_13484.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_211002.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_214687.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_215215.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_215311.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_215339.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_100000014.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_100000015.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_100000033.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000437.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000465.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000485.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000525.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000540.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000541.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000566.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000579.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000619.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000636.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000651.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000654.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000655.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000659.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000704.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000709.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000716.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000725.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000727.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000767.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000771.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000772.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000773.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000836.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000850.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300000853.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300004655.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005072.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005104.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005171.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005213.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005316.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005323.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005354.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005435.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005648.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005677.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005808.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005829.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005839.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005860.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005890.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005962.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300005999.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006003.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006025.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006033.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006171.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006289.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006293.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006351.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006356.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006407.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006409.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006490.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006495.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006498.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006537.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006579.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006584.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006645.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006671.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006797.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300006864.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007084.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007173.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007237.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007318.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007351.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007453.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007494.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007563.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007603.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007621.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007638.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007706.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007718.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007748.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007752.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007773.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007891.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007930.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300007960.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008088.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008096.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008127.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008201.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008202.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008212.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008244.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008270.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008294.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008306.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008339.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008341.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008388.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008393.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008408.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008411.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008481.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008633.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008638.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008645.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008713.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008718.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008770.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008783.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008804.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008819.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008848.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300008924.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009100.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009124.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009129.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009151.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009172.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009182.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009243.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009360.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009411.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009432.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009443.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009460.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009484.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009523.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009528.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009630.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009636.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009639.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009690.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009691.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009692.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009704.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009713.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009733.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009739.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009761.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009784.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009785.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009791.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009799.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009807.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009809.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009815.csv
# Saved: Datasets/Merged_Lake_CSVs\Lake_300009850.csv
